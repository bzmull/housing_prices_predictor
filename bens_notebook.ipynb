# %%
import pandas as pd
from sklearn import linear_model

# %%
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
train_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
unique_count_list = []
for i in train_df.columns:
    unique_count_list.append(len(train_df[i].unique()))

# %%
df_unique = pd.DataFrame({"column_name": list(train_df.columns),"unique_count":unique_count_list})

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also     
    print()

# %%
null_lot = train[train["LotFrontage"].isnull()]
train[train.fillna(0)["LotFrontage"].isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-51c2eb242c2f> in <module>
# ----> 1 null_lot = train[train["LotFrontage"].isnull()]
#       2 train[train.fillna(0)["LotFrontage"].isnull()]
#
# NameError: name 'train' is not defined

# %%
# turns categorical columns into one hot encoded values and appends as
# additional dimensions 
numeric_train = pd.get_dummies(train_df).fillna(0)
X_train = numeric_train.drop(columns="SalePrice")
Y_train = pd.get_dummies(train_df)["SalePrice"]

numeric_test = pd.get_dummies(test_df).fillna(0)
X_test = numeric_test.loc[:, numeric_test.columns]

# %%
print(len(test_df.columns))
# Out:
# 80

# %%
# Quick fix: train set categorical columns had values non-existent in the test set. 
# Said columns are removed from train set data in order to run predict method
missing_columns = list(set(X_train.columns) - set(X_test.columns))
X_train = X_train.drop(missing_columns, axis=1)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, Y_train)
reg.coef_
# Out:
# array([ 4.32033237e-01, -1.13303303e+02, -3.80342999e+01,  5.34832200e-01,
#         7.83602300e+03,  5.30346826e+03,  2.26481799e+02,  6.29512746e+01,
#         2.50863851e+01,  3.98014288e+00,  5.00719357e+00, -2.37812461e+00,
#         6.60919613e+00,  2.07032486e+01,  3.22720210e+01, -3.07314114e+01,
#         2.22437318e+01,  3.78810217e+03,  7.57174134e+02,  5.84888289e+03,
#         1.08357363e+03, -3.14273436e+03, -1.24503814e+04,  2.73559886e+03,
#         4.20874673e+03, -4.25570548e+01,  1.02692632e+04,  1.45219700e+00,
#         1.92485738e+01,  7.27843679e+00,  1.46448174e+00,  4.82531361e+01,
#         2.95222192e+01,  7.60484554e+01,  3.16139101e+00, -3.54651109e+02,
#        -7.21066819e+02, -2.42673933e+04,  1.15990845e+04,  3.99338393e+03,
#         6.12234758e+03,  2.55257733e+03, -1.51876368e+04,  1.51876368e+04,
#         1.33337598e+03,  3.43166361e+03,  2.51760641e+03,  5.12296083e+03,
#        -1.21717818e+04,  4.53121457e+03, -6.95534925e+03,  6.38211737e+03,
#        -4.62964790e+03,  5.20287979e+03,  6.28490236e+04,  3.61475245e+03,
#         1.45708043e+04, -5.70748621e+03, -1.44667302e+04,  1.98865961e+03,
#         2.47009586e+03,  9.66127155e+03, -1.21313674e+04,  1.79045899e+03,
#        -1.78930600e+03,  2.56004606e+03, -4.47656298e+03, -1.08171876e+04,
#        -5.14895781e+03,  1.70818905e+04, -1.94588516e+04, -9.42699734e+03,
#        -1.03852930e+04, -6.95583384e+03, -1.67518091e+04, -1.40866363e+04,
#         8.02254829e+03, -1.69771181e+04,  3.70697013e+04,  2.84965126e+04,
#         8.06837480e+03,  1.15875791e+04,  1.27752814e+04, -6.13701117e+04,
#         2.12706212e+04, -1.70299438e+03, -5.24528272e+03, -2.03166785e+03,
#         7.38111245e+03, -8.79250208e+02,  2.17065981e+04,  4.09978727e+04,
#         4.78241203e+04,  4.07209526e+04,  4.69651124e+04,  4.21858977e+04,
#         8.16051713e+04,  7.83858273e+04,  8.04095551e+04, -1.24845181e+05,
#        -1.08456536e+05, -1.45199559e+05, -1.15736046e+05, -4.01326980e+04,
#         6.82284266e+04,  7.45813867e+04,  7.02764647e+04,  6.74469737e+04,
#        -1.14242217e+02, -1.29658083e+03,  1.41082304e+03,  1.09358553e+05,
#        -1.28432086e+05, -6.64336940e+03, -2.70546174e+03,  1.81783429e+02,
#        -6.38872813e+03, -7.07715862e+04,  4.75413996e+03, -2.01333296e+03,
#        -1.27811410e+04,  6.61125087e+03,  1.72679050e+04,  5.41306687e+03,
#        -7.28745356e+03, -1.46909806e+04,  2.16053217e+04, -2.36052857e+03,
#        -1.37774406e+04, -2.22600123e+03, -3.17812877e+03,  1.47363748e+04,
#         9.24818327e+02,  5.72228974e+03, -1.59793529e+04])

# %%
preds = reg.predict(X_test)

# %%
len(preds)
# Out:
# 1459

# %%
len(X_test["Id"])
# Out:
# 1459

# %%
test_df["Condition2"].unique()

# %%
train_df["Condition2"].unique()

# %%
submit_df = pd.DataFrame({"Id":X_test["Id"], "SalePrice":preds})

# %%
submit_df.to_csv('C:\\Users\\Binyamin\\PythonProjects\\housing_prices_predictor\\submit_df.csv')

# %%
pwd
# Out:
# 'C:\\Users\\Binyamin\\PythonProjects\\housing_prices_predictor'

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is BA05-5E0F
#
#  Directory of C:\Users\Binyamin\PythonProjects\housing_prices_predictor
#
# 02/18/2020  12:13 PM    <DIR>          .
# 02/18/2020  12:13 PM    <DIR>          ..
# 01/01/2020  07:30 PM                26 .gitignore
# 01/19/2020  10:47 PM    <DIR>          .ipynb_checkpoints
# 02/18/2020  12:13 PM            85,600 bens_notebook.ipynb
# 01/01/2020  07:37 PM    <DIR>          data
# 01/19/2020  10:47 PM            80,049 jr_notebook.ipynb
# 01/07/2020  08:11 PM               523 resources.txt
# 02/18/2020  12:13 PM            42,095 submit_df.csv
#                5 File(s)        208,293 bytes
#                4 Dir(s)  31,999,660,032 bytes free

# %%
pd.read_csv('sample_submission.csv')
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# 5     1466  177150.989247
# 6     1467  172070.659229
# 7     1468  175110.956520
# 8     1469  162011.698832
# 9     1470  160726.247831
# 10    1471  157933.279456
# 11    1472  145291.245020
# 12    1473  159672.017632
# 13    1474  164167.518302
# 14    1475  150891.638244
# 15    1476  179460.965187
# 16    1477  185034.628914
# 17    1478  182352.192645
# 18    1479  183053.458214
